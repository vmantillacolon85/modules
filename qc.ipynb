# %%
import pandas as pd 
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 
import seaborn as sns 

#load data
qc_df = pd.read_csv("AB_QC_2022.csv")

#summary
# print("Rows     :",qc_df.shape[0])
# print("Columns  :",qc_df.shape[1])
# print("\nFeatures :\n",qc_df.columns.tolist())
# print("\nMissing Value    :",qc_df.isnull().sum().sum())
# print("\nColumns with missing value:\n",qc_df.isnull().any())

#drop unnecessary columns
qc_df.drop(['id','name','host_name','last_review'], axis=1, inplace=True)
print(qc_df.head())

#replacing all NaN values in 'reviews_per_month' with 0
qc_df.reviews_per_month.fillna(0, inplace=True)
print(qc_df.isnull().any())

# #Neighbourhood Group
# plt.style.use('fivethirtyeight')
# plt.figure(figsize=(13,7))
# plt.title("Neighbourhood Group")
# g = plt.pie(qc_df.neighbourhood_group.value_counts(), labels=qc_df.neighbourhood_group.value_counts().index,autopct='%1.1f%%', startangle=180)
# plt.show()

# #Map of neighbourhood group
# plt.figure(figsize=(13,7))
# plt.title("Map of Neighbourhood Group")
# sns.scatterplot(qc_df.longitude,qc_df.latitude,hue=qc_df.neighbourhood_group)
# plt.ioff()
# plt.show()

# #Room type
# plt.figure(figsize=(13,7))
# plt.title("Type of Room")
# sns.countplot(qc_df.room_type, palette="muted")
# fig = plt.gcf()
# plt.show()

# plt.figure(figsize=(13,7))
# plt.title("Room Type on Neighbourhood Group")
# sns.countplot(qc_df.neighbourhood_group,hue=qc_df.room_type, palette="muted")
# plt.show()

# #Neighbourhood Group vs. Availability Room
# plt.style.use('classic')
# plt.figure(figsize=(13,7))
# plt.title("Neighbourhood Group vs. Availability Room")
# sns.boxplot(data=qc_df, x='neighbourhood_group',y='availability_365',palette="dark")
# plt.show()

# #Neighbourhood Group Price Distribution
# #Price Varies vs. Area
# plt.figure(figsize=(13,7))
# plt.title("Map of Price Distribution")
# ax=qc_df[qc_df.price<500].plot(kind='scatter', x='longitude',y='latitude',label='availability_365',c='price',cmap=plt.get_cmap('jet'),colorbar=True,alpha=0.4)
# ax.legend()
# plt.ioff()
# plt.show()

# plt.style.use('classic')
# plt.figure(figsize=(13,7))
# plt.title("Neighbourhood Group Price Distribution < 500")
# sns.boxplot(y="price",x ='neighbourhood_group' ,data = qc_df[qc_df.price<500])
# plt.show()

# #correlation
# corr = qc_df.corr(method='kendall')
# plt.figure(figsize=(13,10))
# plt.title("Correlation Between Different Variables\n")
# sns.heatmap(corr, annot=True)
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/4m/yt8hbrd947q4lr3s_f31chk00000gn/T/ipykernel_25997/2073597964.py in <module>
#       6
#       7 #load data
# ----> 8 qc_df = pd.read_csv("AB_QC_2022.csv")
#       9
#      10 #summary
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
